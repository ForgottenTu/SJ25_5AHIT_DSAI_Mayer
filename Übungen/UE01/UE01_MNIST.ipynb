# %%
import pandas as pd
import numpy as np
from keras.models import Model
from keras.layers import Input, Dense
from keras.datasets import mnist
import tensorflow as tf


(x_train, y_train) , (x_test, y_test) = mnist.load_data("mnist.npz")
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_train = pd.DataFrame(x_train.reshape(x_train.shape[0], x_train.shape[1]*x_train.shape[2]))
y_train = pd.DataFrame(y_train)

y_train_cat = tf.keras.utils.to_categorical(y_train, num_classes=10)

x_train_np = x_train.values.astype("float32")

# %%
x_flatten = np.ndarray.flatten(x_train)

# %%
inputs = Input(shape=(784,))

x = Dense(units=64, activation='relu')(inputs)

outputs = Dense(units=10, activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

model.fit(x_train_np, y_train_cat, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 6s 3ms/step - accuracy: 0.7764 - loss: 2.1940
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.8877 - loss: 0.4433
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9179 - loss: 0.3077
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9259 - loss: 0.2779
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 5s 3ms/step - accuracy: 0.9308 - loss: 0.2537

# %%
x_test = pd.DataFrame(x_test.reshape(x_test.shape[0], x_test.shape[1]*x_test.shape[2]))


y_test = pd.DataFrame(y_test)

y_test_cat = tf.keras.utils.to_categorical(y_test, num_classes=10)
x_test_np = x_test.values.astype('float32')

# %%
loss, accuracy = model.evaluate(x_test_np,y_test_cat)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9328 - loss: 0.2760
