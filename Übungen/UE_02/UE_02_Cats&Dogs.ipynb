# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import re
import keras
from keras import layers
from keras.src.legacy.preprocessing.image import ImageDataGenerator
from keras.src.utils import load_img
from sklearn.model_selection import train_test_split

filenames = os.listdir("./cat_dog-train/train")

pictures_train = pd.DataFrame(columns=['filename', 'label'])

pictures_train['filename'] = filenames
pictures_train['label'] = pictures_train['filename'].str.extract(r'(cat|dog)', expand=False, flags=re.IGNORECASE)

filenames = os.listdir("./cat_dog-test1/test1")

pictures_test = pd.DataFrame(columns=['filename', 'label'])

pictures_test['filename'] = filenames
pictures_test['label'] = pictures_test['filename'].str.extract(r'(cat|dog)', expand=False, flags=re.IGNORECASE)

# %%
test_dir = os.path.join('.', 'cat_dog-test1', 'test1')
filenames_test = sorted(os.listdir(test_dir))

train_dir = os.path.join('.', 'cat_dog-train', 'train')
filenames = sorted(os.listdir(train_dir))

train_images = []
for image_name in pictures_train['filename']:
    path = os.path.join(train_dir, image_name)
    with open(path, 'rb') as f:
        train_images.append(f.read())

test_images = []
for image_name in pictures_test['filename']:
    path = os.path.join(test_dir, image_name)
    with open(path, 'rb') as f:
        test_images.append(f.read())

data_train = pd.DataFrame({
    'filename': pictures_train['filename'],
    'label': pictures_train['label'],
    'image_bytes': train_images
})

data_test = pd.DataFrame({
    'filename': pictures_test['filename'],
    'label': pictures_test['label'],
    'image_bytes': test_images
})

# %%
model = keras.Sequential()

model.add(layers.Input(shape=(150, 150, 3)))

model.add(layers.Conv2D(16, kernel_size=(3, 3), activation='silu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(32, kernel_size=(3, 3), activation='silu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.Conv2D(64, kernel_size=(3, 3), activation='silu'))
model.add(layers.MaxPooling2D(pool_size=(2, 2)))

model.add(layers.GlobalMaxPooling2D())
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_df, valid_df = train_test_split(data_train, test_size=0.2, random_state=42, stratify=data_train['label'])

train_df = train_df.reset_index(drop=True)
valid_df = valid_df.reset_index(drop=True)

# %%
print(train_df.shape)
print(valid_df.shape)
# Out:
# (20000, 3)
# (5000, 3)

# %%
train_datagen = ImageDataGenerator(rescale=1./255)
valid_datagen = ImageDataGenerator(rescale=1./255)

# %%
train_generator = train_datagen.flow_from_dataframe(
    dataframe=train_df,
    directory='./cat_dog-train/train',
    x_col='filename',
    y_col='label',
    target_size=(150, 150),
    batch_size=64,
    class_mode='binary'
)

valid_generator = valid_datagen.flow_from_dataframe(
    dataframe=valid_df,
    directory='./cat_dog-train/train',
    x_col='filename',
    y_col='label',
    target_size=(150, 150),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 20000 validated image filenames belonging to 2 classes.
# Found 5000 validated image filenames belonging to 2 classes.

# %%
for data_batch, labels_batch in train_generator:
    print(data_batch.shape)
    print(labels_batch.shape)
    break
# Out:
# (64, 150, 150, 3)
# (64,)

# %%
history = model.fit(train_generator, steps_per_epoch=312, validation_data=valid_generator, epochs=10)
# Out:
# C:\Users\julia\anaconda3\Lib\site-packages\keras\src\trainers\data_adapters\py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# Epoch 1/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 184s 585ms/step - accuracy: 0.6099 - loss: 0.6517 - val_accuracy: 0.6686 - val_loss: 0.6126
# Epoch 2/10
#   1/312 ━━━━━━━━━━━━━━━━━━━━ 50s 163ms/step - accuracy: 0.6719 - loss: 0.5909
# C:\Users\julia\anaconda3\Lib\site-packages\keras\src\trainers\epoch_iterator.py:116: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self._interrupted_warning()
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.6719 - loss: 0.5909 - val_accuracy: 0.6696 - val_loss: 0.6105
# Epoch 3/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 128s 411ms/step - accuracy: 0.6887 - loss: 0.5896 - val_accuracy: 0.7058 - val_loss: 0.5718
# Epoch 4/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.6406 - loss: 0.5855 - val_accuracy: 0.7034 - val_loss: 0.5725
# Epoch 5/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 109s 351ms/step - accuracy: 0.7208 - loss: 0.5518 - val_accuracy: 0.7366 - val_loss: 0.5252
# Epoch 6/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 38ms/step - accuracy: 0.7500 - loss: 0.5681 - val_accuracy: 0.7272 - val_loss: 0.5316
# Epoch 7/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 91s 293ms/step - accuracy: 0.7567 - loss: 0.5046 - val_accuracy: 0.7658 - val_loss: 0.5001
# Epoch 8/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 12s 37ms/step - accuracy: 0.7656 - loss: 0.5061 - val_accuracy: 0.7452 - val_loss: 0.5332
# Epoch 9/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 103s 331ms/step - accuracy: 0.7790 - loss: 0.4660 - val_accuracy: 0.7834 - val_loss: 0.4605
# Epoch 10/10
# 312/312 ━━━━━━━━━━━━━━━━━━━━ 14s 46ms/step - accuracy: 0.7500 - loss: 0.5325 - val_accuracy: 0.7748 - val_loss: 0.4687

# %%
test_datagen = ImageDataGenerator(rescale=1./255)
test_generator = test_datagen.flow_from_dataframe(
    dataframe=data_test,
    directory='./cat_dog-test1/test1',
    x_col='filename',
    y_col=None,
    class_mode=None,
    target_size=(150, 150),
    batch_size=32,
    shuffle=False,
)
# Out:
# Found 12500 validated image filenames.

# %%
test_generator.reset()
predict = model.predict(test_generator, verbose=1)
# Out:
# 391/391 ━━━━━━━━━━━━━━━━━━━━ 90s 232ms/step

# %%
predict_rounded = np.round(predict).astype(int).flatten()
data_test['label'] = predict_rounded
data_test.head(50)
# Out:
#      filename  label                                        image_bytes
# 0       1.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 1      10.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 2     100.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 3    1000.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 4   10000.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 5   10001.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 6   10002.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 7   10003.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 8   10004.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 9   10005.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 10  10006.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 11  10007.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 12  10008.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 13  10009.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 14   1001.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 15  10010.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 16  10011.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 17  10012.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 18  10013.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 19  10014.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 20  10015.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 21  10016.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 22  10017.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 23  10018.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 24  10019.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 25   1002.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 26  10020.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 27  10021.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 28  10022.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 29  10023.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 30  10024.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 31  10025.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 32  10026.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 33  10027.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 34  10028.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 35  10029.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 36   1003.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 37  10030.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 38  10031.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 39  10032.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 40  10033.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 41  10034.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 42  10035.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 43  10036.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 44  10037.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 45  10038.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 46  10039.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 47   1004.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 48  10040.jpg      0  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...
# 49  10041.jpg      1  b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00...

# %%
testsample_df = data_test.head(30)

testsample_df.head(100)

plt.figure(figsize=(12, 24))

for index, row in testsample_df.iterrows():
    filenames = row['filename']
    label = row['label']
    img = load_img("./cat_dog-test1/test1/" + filenames, target_size=(150, 150))
    plt.subplot(10, 10, index + 1)
    plt.imshow(img)
    plt.xlabel(f"(filenames[index]): {label}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 testsample_df = data_test.head(30)
#       3 testsample_df.head(100)
#       5 plt.figure(figsize=(12, 24))
#
# NameError: name 'data_test' is not defined
