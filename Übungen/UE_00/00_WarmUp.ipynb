# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

movies = pd.DataFrame(pd.read_csv("./movie.csv"))
spam = pd.DataFrame(pd.read_csv("./spam.csv", encoding = "ISO-8859-1" ))

movies.shape
# Out:
# (4916, 28)

# %%
type(movies["movie_title"])
# Out:
# pandas.core.series.Series

# %%
movies["has_seen"] = np.zeros([])

# %%
movies["director_actor_facebook_likes"] = movies["director_facebook_likes"].fillna(0) + movies['cast_total_facebook_likes']

movies["director_actor_facebook_likes"].isna().sum()


movies
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# ...

# %%
movies.describe()

plt.bar(movies.index, movies["budget"])
plt.xlabel("Movies")
plt.ylabel("Budget")
plt.yscale("log")
plt.grid
plt.show()

# %%
spam["length"] = spam["v2"].str.len()
spam.head()
